# %% [markdown]
# <a href="https://colab.research.google.com/github/IcarusFe1l/ArkadasimHG/blob/main/Task1BK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dfpv = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_data.csv')

# %%
dfpv.head()
# Out:
#                                      player               team  \
# 0        /david-de-gea/profil/spieler/59377  Manchester United
# 1       /jack-butland/profil/spieler/128899  Manchester United
# 2          /tom-heaton/profil/spieler/34130  Manchester United
# 3  /lisandro-martinez/profil/spieler/480762  Manchester United
# 4     /raphael-varane/profil/spieler/164770  Manchester United
#
#                 name              position  height   age  appearance  \
# 0       David de Gea            Goalkeeper   189.0  32.0         104
# 1       Jack Butland            Goalkeeper   196.0  30.0          15
# 2         Tom Heaton            Goalkeeper   188.0  37.0           4
# 3  Lisandro Martínez  Defender Centre-Back   175.0  25.0          82
# 4     Raphaël Varane  Defender Centre-Back   191.0  30.0          63
#
#       goals   assists  yellow cards  ...  goals conceded  clean sheets  \
# 0  0.000000  0.000000      0.009585  ...        1.217252      0.335463
# ...

# %%
dfpv.describe(include='all')
# Out:
#                                     player                  team      name  \
# count                                10754                 10754     10754
# unique                               10754                   374     10584
# top     /david-de-gea/profil/spieler/59377  Daejeon Hana Citizen  Paulinho
# freq                                     1                    46         6
# mean                                   NaN                   NaN       NaN
# std                                    NaN                   NaN       NaN
# min                                    NaN                   NaN       NaN
# 25%                                    NaN                   NaN       NaN
# 50%                                    NaN                   NaN       NaN
# 75%                                    NaN                   NaN       NaN
# max                                    NaN                   NaN       NaN
#
# ...

# %%
dfpv["position"].value_counts()
# Out:
# position
# Defender Centre-Back          1821
# Attack Centre-Forward         1353
# Goalkeeper                    1229
# midfield-CentralMidfield      1149
# midfield-DefensiveMidfield     900
# Defender Right-Back            867
# Defender Left-Back             807
# midfield-AttackingMidfield     769
# Attack-RightWinger             717
# Attack-LeftWinger              714
# midfield-RightMidfield         102
# midfield-LeftMidfield          100
# midfield                        75
# Attack-SecondStriker            65
# Attack                          53
# Defender                        33
# Name: count, dtype: int64

# %%
#dfGoalkeeper = dfTips[dfTips['position']=='GK']
#dfDefender = dfTips[dfTips['position'] == ['Defender Centre-Back','Defender Right-Back','Defender Left-Back','Defender']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-5be636032840> in <cell line: 2>()
#       1 dfGoalkeeper = dfTips[dfTips['position']=='GK']
# ----> 2 dfDefender = dfTips[dfTips['position'] == ['Defender Centre-Back','Defender Right-Back','Defender Left-Back','Defender']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      79         other = item_from_zerodim(other)
#      80
# ---> 81         return method(self, other)
#      82
#      83     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __eq__(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#      41
#      42     @unpack_zerodim_and_defer("__ne__")
#
# ...

# %%
#show me the correlation  between attributes of the data
dfpv.corr( numeric_only=1

           )
#let's also plot this correlation with heatmap
import seaborn as sns
sns.heatmap(dfpv.corr( numeric_only=1

           ))
# Out:
# <Axes: >

# %%
# Assign independent(Y) and dependent(X) variables
X = dfpv.loc[:,['minutes played','assists','goals','age','appearance','award','highest_value']]
Y = dfpv.loc[:,['current_value']]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, Y)
# Out:
# LinearRegression()

# %%
# Display regression model
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  [5787134.80397406]
# Coefficients:
#  [[ 1.20940664e+03  1.14249259e+06  8.15232926e+05 -2.44537333e+05
#   -5.42975502e+04 -3.51035774e+05  5.97997880e-01]]

# %%
New_Minutes_Played = 60
New_Assists = 7
New_Goals = 4
New_Age = 25
New_appearance = 85
New_award = 10
New_highest_value = 1500000
print ('Predicted Value: \n', regr.predict([[New_Minutes_Played ,New_Assists,New_Goals,New_Age,New_appearance,New_award,New_highest_value]]))
# Out:
# Predicted Value:
#  [[3775993.02989085]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Set data fields
y = dfpv.loc[:,'current_value']

# Show plot
plt.hist(y, )
plt.xlabel('PV')
plt.ylabel('Count')
plt.show()

# %%
# Set data fields
x = dfpv.loc[:,'minutes played']
y = dfpv.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfpv.loc[:,'minutes played']))
plt.ylim(0,np.max(dfpv.loc[:,'current_value']))
plt.xlabel('Mins played')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfpv.loc[:,'age']
y = dfpv.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfpv.loc[:,'age']))
plt.ylim(0,np.max(dfpv.loc[:,'current_value']))
plt.xlabel('Age')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfpv.loc[:,'assists']
y = dfpv.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfpv.loc[:,'assists']))
plt.ylim(0,np.max(dfpv.loc[:,'current_value']))
plt.xlabel('Assists')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfpv.loc[:,'goals']
y = dfpv.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfpv.loc[:,'goals']))
plt.ylim(0,np.max(dfpv.loc[:,'current_value']))
plt.xlabel('Goals')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfpv.loc[:,'appearance']
y = dfpv.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfpv.loc[:,'appearance']))
plt.ylim(0,np.max(dfpv.loc[:,'current_value']))
plt.xlabel('Appearance')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfpv.loc[:,'award']
y = dfpv.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfpv.loc[:,'award']))
plt.ylim(0,np.max(dfpv.loc[:,'current_value']))
plt.xlabel('Award')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfpv.loc[:,'highest_value']
y = dfpv.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfpv.loc[:,'highest_value']))
plt.ylim(0,np.max(dfpv.loc[:,'current_value']))
plt.xlabel('Highest Value')
plt.ylabel('Current Value')
plt.show()

# %% [markdown]
# At this initial stage I tried to showcase all the "attributes" and see their correlation with the current value. In the initial heatmap I thought the attributes I selected according to their colour was correct. However in order to see if they are correlated or not by eye, I plotted each one of them. And I ended up realising that some of them not correlated with current value and some like highest value directly correlated with it.

# %% [markdown]
# In the second stage I will try to group the data according to their attribute such as defender, goalkeeer, attack and midfield to analyze it even more accurately.

# %% [markdown]
# Since for example according to logic I build a value of a defender and attacker won't be effected the same way from scoring or denying a goal.

# %%
# Given data
data = {
    "position": [
        "Defender Centre-Back", "Attack Centre-Forward", "Goalkeeper",
        "midfield-CentralMidfield", "midfield-DefensiveMidfield", "Defender Right-Back",
        "Defender Left-Back", "midfield-AttackingMidfield", "Attack-RightWinger",
        "Attack-LeftWinger", "midfield-RightMidfield", "midfield-LeftMidfield",
        "midfield", "Attack-SecondStriker", "Attack", "Defender"
    ],
    "count": [
        1821, 1353, 1229, 1149, 900, 867, 807, 769, 717, 714,
        102, 100, 75, 65, 53, 33
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Define the categories and their respective positions
categories = {
    "Defender": ["Defender Centre-Back", "Defender Right-Back", "Defender Left-Back", "Defender"],
    "Attack": ["Attack Centre-Forward", "Attack-RightWinger", "Attack-LeftWinger", "Attack-SecondStriker", "Attack"],
    "Goalkeeper": ["Goalkeeper"],
    "Midfield": ["midfield-CentralMidfield", "midfield-DefensiveMidfield", "midfield-AttackingMidfield",
                 "midfield-RightMidfield", "midfield-LeftMidfield", "midfield"]
}

# Initialize a dictionary to store the merged counts
merged_counts = {key: 0 for key in categories.keys()}

# Sum counts for each category
for category, positions in categories.items():
    merged_counts[category] = df[df["position"].isin(positions)]["count"].sum()

# Convert the merged counts player	team	name	position	height	age	appearance	goals	assists	yellow cards	goals conceded	clean sheets	minutes played	days_injured	games_injured	award	current_value	highest_value	position_encoded	winger dictionary to a DataFrame
merged_counts = {key: value for key, value in merged_counts.items() if value > 0}
#merged_df = pd.DataFrame(list(merged_counts.items()), columns=["position", "count"])

print(merged_df)
# Out:
#      position  count
# 0    Defender   3528
# 1      Attack   2902
# 2  Goalkeeper   1229
# 3    Midfield   3095

# %%
#show me the correlation  between attributes of the data
dfDefender.corr( numeric_only=1

           )
#let's also plot this correlation with heatmap
import seaborn as sns
sns.heatmap(dfDefender.corr( numeric_only=1

           ))
# Out:
# <Axes: >

# %% [markdown]
# Hocam at this stage I guess, I totally messed it up :( and I couldn't figure how to group the data the way I want, basically according to their positions. I wanted to group the data like I wanted to indicate defender as one but like it has sub groups. For example I wanted to analyze defenders in it's own sub group. When I analyze defenders I will be analyzing these 4 positions:("Defender Centre-Back", "Defender Right-Back", "Defender Left-Back", "Defender") etc.

# %% [markdown]
# Since I couldn't conclude with the way I wanted, Instead of grouping I will spend more time and check them individually!

# %%
#substract the Defender's data from dfpv
dfDefender = dfpv[dfpv['position'].isin(['Defender Centre-Back', 'Defender Right-Back', 'Defender Left-Back', 'Defender'])]
dfDefender.describe(include='all')
#show me the correlation  between attributes of the data
dfDefender.corr( numeric_only=1

           )
#let's also plot this correlation with heatmap
import seaborn as sns
sns.heatmap(dfDefender.corr( numeric_only=1

           ))
# Out:
# <Axes: >

# %% [markdown]
# I thought I wouldn't be able to do it but here we are...

# %% [markdown]
# I will assume that I managed to do it and replicate what I have done above part.

# %% [markdown]
# Positive correlations: "Appearance," ,"minutes played," and "award"
# "Highest value" has the strongest correlation among them.
#
# Negative correlations:"Days injured" and "games injured" have slight negative correlation.
# "Position encoded" and "winger" have slight to moderate negative correlation
#
# No Significant Correlation: "Goals conceded"

# %% [markdown]
# **THERE IS A ONE ISSUE THO!**
# Since we are working with defence it is by nature that it doesn't have any goals concended and clean sheets!!! So these 2 variable might seem like they are related with current value HOWEVER THEY ARE NOT!

# %%
# Assign independent(Y) and dependent(X) variables
X = dfDefender.loc[:,['minutes played','appearance','award','highest_value']]
Y = dfDefender.loc[:,['current_value']]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, Y)
# Out:
# LinearRegression()

# %%
# Display regression model
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  [-225442.27208287]
# Coefficients:
#  [[ 8.97589176e+02 -4.51058442e+04 -3.99748284e+05  6.42119913e-01]]

# %%
New_Minutes_Played = 60

New_appearance = 85
New_award = 10
New_highest_value = 15000000
print ('Predicted Value: \n', regr.predict([[New_Minutes_Played ,New_appearance,New_award,New_highest_value]]))
# Out:
# Predicted Value:
#  [[1628732.17468684]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Set data fields
y = dfDefender.loc[:,'current_value']

# Show plot
plt.hist(y, )
plt.xlabel('PV')
plt.ylabel('Count')
plt.show()

# %%
# Set data fields
x = dfDefender.loc[:,'minutes played']
y = dfDefender.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfDefender.loc[:,'minutes played']))
plt.ylim(0,np.max(dfDefender.loc[:,'current_value']))
plt.xlabel('Mins played')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfDefender.loc[:,'appearance']
y = dfDefender.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfDefender.loc[:,'appearance']))
plt.ylim(0,np.max(dfDefender.loc[:,'current_value']))
plt.xlabel('Appearance')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfDefender.loc[:,'award']
y = dfDefender.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfDefender.loc[:,'award']))
plt.ylim(0,np.max(dfDefender.loc[:,'current_value']))
plt.xlabel('Award')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfDefender.loc[:,'highest_value']
y = dfDefender.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfDefender.loc[:,'highest_value']))
plt.ylim(0,np.max(dfDefender.loc[:,'current_value']))
plt.xlabel('Highest value')
plt.ylabel('Current Value')
plt.show()

# %% [markdown]
# Now let's do it for Goal Keeper

# %%
#substract the Defender's data from dfpv
dfGoalkeeper = dfpv[dfpv['position'].isin(['Goalkeeper'])]
dfGoalkeeper.describe(include='all')
#show me the correlation  between attributes of the data
dfGoalkeeper.corr( numeric_only=1

           )
#let's also plot this correlation with heatmap
import seaborn as sns
sns.heatmap(dfGoalkeeper.corr( numeric_only=1

           ))
# Out:
# <Axes: >

# %%
# Assign independent(Y) and dependent(X) variables
X = dfGoalkeeper.loc[:,['minutes played','appearance','highest_value']]
Y = dfGoalkeeper.loc[:,['current_value']]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, Y)
# Out:
# LinearRegression()

# %%
# Display regression model
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  [-295517.11265096]
# Coefficients:
#  [[ 2.95087917e+03 -2.45640374e+05  4.61269307e-01]]

# %%
New_Minutes_Played = 60

New_appearance = 20

New_highest_value = 35000000
print ('Predicted Value: \n', regr.predict([[New_Minutes_Played ,New_appearance,New_highest_value]]))
# Out:
# Predicted Value:
#  [[11113153.89633423]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Set data fields
y = dfGoalkeeper.loc[:,'current_value']

# Show plot
plt.hist(y, )
plt.xlabel('PV')
plt.ylabel('Count')
plt.show()

# %%
# Set data fields
x = dfGoalkeeper.loc[:,'minutes played']
y = dfGoalkeeper.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfGoalkeeper.loc[:,'minutes played']))
plt.ylim(0,np.max(dfGoalkeeper.loc[:,'current_value']))
plt.xlabel('Mins played')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfGoalkeeper.loc[:,'appearance']
y = dfGoalkeeper.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfGoalkeeper.loc[:,'appearance']))
plt.ylim(0,np.max(dfGoalkeeper.loc[:,'current_value']))
plt.xlabel('Appearance')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfGoalkeeper.loc[:,'highest_value']
y = dfGoalkeeper.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfGoalkeeper.loc[:,'highest_value']))
plt.ylim(0,np.max(dfGoalkeeper.loc[:,'current_value']))
plt.xlabel('Highest value')
plt.ylabel('Current Value')
plt.show()

# %% [markdown]
# Midfield time

# %%
dfMF = dfpv[dfpv['position'].isin(['midfield-CentralMidfield','midfield-AttackingMidfield','midfield-RightMidfield','midfield-LeftMidfield','midfield-DefensiveMidfield','midfield'])]
dfMF.describe(include='all')
#show me the correlation  between attributes of the data
dfMF.corr( numeric_only=1

           )
#let's also plot this correlation with heatmap
import seaborn as sns
sns.heatmap(dfMF.corr( numeric_only=1

           ))
# Out:
# <Axes: >

# %%
# Assign independent(Y) and dependent(X) variables
X = dfMF.loc[:,['minutes played','appearance','highest_value']]
Y = dfMF.loc[:,['current_value']]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, Y)
# Out:
# LinearRegression()

# %%
# Display regression model
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  [-455990.32258304]
# Coefficients:
#  [[ 1.44391488e+03 -7.60824742e+04  5.77608306e-01]]

# %%
New_Minutes_Played = 60

New_appearance = 20

New_highest_value = 35000000
print ('Predicted Value: \n', regr.predict([[New_Minutes_Played ,New_appearance,New_highest_value]]))
# Out:
# Predicted Value:
#  [[18325285.80185015]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Set data fields
y = dfMF.loc[:,'current_value']

# Show plot
plt.hist(y, )
plt.xlabel('PV')
plt.ylabel('Count')
plt.show()

# %%
# Set data fields
x = dfMF.loc[:,'minutes played']
y = dfMF.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfMF.loc[:,'minutes played']))
plt.ylim(0,np.max(dfMF.loc[:,'current_value']))
plt.xlabel('Mins played')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfMF.loc[:,'appearance']
y = dfMF.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfMF.loc[:,'appearance']))
plt.ylim(0,np.max(dfMF.loc[:,'current_value']))
plt.xlabel('Appearance')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfMF.loc[:,'highest_value']
y = dfMF.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfMF.loc[:,'highest_value']))
plt.ylim(0,np.max(dfMF.loc[:,'current_value']))
plt.xlabel('Highest Value')
plt.ylabel('Current Value')
plt.show()

# %% [markdown]
# Lastly I will do it for the offense aka Attack end conclude my analysis.

# %%
dfA = dfpv[dfpv['position'].isin(['Attack Centre-Forward','Attack-RightWinger','Attack-LeftWinger','Attack-SecondStriker','Attack'])]
dfA.describe(include='all')
#show me the correlation  between attributes of the data
dfA.corr( numeric_only=1

           )
#let's also plot this correlation with heatmap
import seaborn as sns
sns.heatmap(dfA.corr( numeric_only=1

           ))
# Out:
# <Axes: >

# %%
# Assign independent(Y) and dependent(X) variables
X = dfMF.loc[:,['minutes played','appearance','highest_value','award']]
Y = dfMF.loc[:,['current_value']]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, Y)
# Out:
# LinearRegression()

# %%
# Display regression model
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  [15500.33979391]
# Coefficients:
#  [[ 1.33011494e+03 -6.61881526e+04  6.50911019e-01 -5.57036743e+05]]

# %%
New_Minutes_Played = 60

New_appearance = 85
New_award = 10
New_highest_value = 15000000
print ('Predicted Value: \n', regr.predict([[New_Minutes_Played ,New_appearance,New_award,New_highest_value]]))
# Out:
# Predicted Value:
#  [[-8.35555668e+12]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Set data fields
y = dfA.loc[:,'current_value']

# Show plot
plt.hist(y, )
plt.xlabel('PV')
plt.ylabel('Count')
plt.show()

# %%
# Set data fields
x = dfA.loc[:,'minutes played']
y = dfA.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfA.loc[:,'minutes played']))
plt.ylim(0,np.max(dfA.loc[:,'current_value']))
plt.xlabel('Mins played')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfA.loc[:,'appearance']
y = dfA.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfA.loc[:,'appearance']))
plt.ylim(0,np.max(dfA.loc[:,'current_value']))
plt.xlabel('Appearance')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfA.loc[:,'award']
y = dfA.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfA.loc[:,'award']))
plt.ylim(0,np.max(dfA.loc[:,'current_value']))
plt.xlabel('Award')
plt.ylabel('Current Value')
plt.show()

# %%
# Set data fields
x = dfA.loc[:,'highest_value']
y = dfA.loc[:,'current_value']
# Generate trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# Show plot
plt.scatter(x, y)
plt.plot(x,p(x),"r--")
plt.xlim(0,np.max(dfA.loc[:,'highest_value']))
plt.ylim(0,np.max(dfA.loc[:,'current_value']))
plt.xlabel('Highest value')
plt.ylabel('Current Value')
plt.show()

# %% [markdown]
# As conclusion in the analysis I found that Attack and Defender positions are correlated with same attributes. However after applying linear regression coefficient of the attributes differs. By using same parameter values we get different results. Therefore it supports my idea of seperating positions from each other since every position has different interraction with the attributes.

# %% [markdown]
# We knew that what I have done initially wasn't completely correct or wrong but it didn't provide accurate information for us to analyze. This new method provides more accurate and focused data for us.

# %% [markdown]
# Thank you for reading! I hope you enjoyed!
#
# Bora Kol
